# %% [markdown]
# # Metrics for EuRoC

# %%
from copy import copy
import os
import numpy as np
import sys
import pandas as pd 
# Import local code
bachelorpath = os.path.normpath(os.getcwd() + os.sep + os.pardir)
scriptpath = bachelorpath + '/scripts/'
sys.path.insert(0, scriptpath)
import BP_ratio as bp
import dataset_plotting as dp
import motion_blur as mb 
import entropy as en
import importlib
importlib.reload(bp)
importlib.reload(dp)
importlib.reload(mb)
importlib.reload(en)
import tkinter as tk
from tkinter import filedialog

def select_file():
    root = tk.Tk()
    root.withdraw()
    file_path = filedialog.askopenfilename()
    return file_path
def select_dir():
    root = tk.Tk()
    root.withdraw()
    dir_path = filedialog.askdirectory()
    return dir_path

# %% [markdown]
# # EuRoC
# The EuRoC dataset is accessed at their own website: [EuRoC](https://www.lirmm.fr/aqualoc/)

# %% [markdown]
# ## Brightness metrics

# %% [markdown]
# ### Machine Hall
# These datasets are recorded on the website with various difficulties. First load data:

# %%
euroc_b_metrics = bp.load_euroc_dataset(True)
# Out:
# Scanning next folder current total of images processed:  3682
# Scanning next folder current total of images processed:  7364
# Scanning next folder current total of images processed:  10404
# Scanning next folder current total of images processed:  13444
# Scanning next folder current total of images processed:  16144
# Scanning next folder current total of images processed:  18844
# Scanning next folder current total of images processed:  20877
# Scanning next folder current total of images processed:  22909
# Scanning next folder current total of images processed:  25182
# Scanning next folder current total of images processed:  27455
# Scanning next folder current total of images processed:  30367
# Scanning next folder current total of images processed:  33279
# Scanning next folder current total of images processed:  34989
# Scanning next folder current total of images processed:  36700
# Scanning next folder current total of images processed:  38849
# ...

# %%
euroc_data_br, euroc_data_m, euroc_data_delta = euroc_b_metrics

# %% [markdown]
# #### Machine Hall 01

# %%
dp.create_b_histogram_euroc(euroc_b_metrics,0)

# %%
dp.print_euroc_b_metrics(euroc_b_metrics, 0, False)
# Out:
# Combined pixel ratio of both cams:  0.7443348745252552
# Combined pixel ratio variance on both cams:  0.10103713905672043
# Combined mean image intensity of both cams:  0.3399640917778015
# Combined mean image intensity variance of both cams:  0.04604704335339844
# Largest delta: (pixel ratio, mean)  [0.8385280272012131, 0.3705512583255768]

# %% [markdown]
# ### Machine Hall 02

# %%
dp.create_b_histogram_euroc(euroc_b_metrics,1)

# %%
dp.print_euroc_b_metrics(euroc_b_metrics, 1, False)
# Out:
# Combined pixel ratio of both cams:  0.75024455093286
# Combined pixel ratio variance on both cams:  0.10462466476420373
# Combined mean image intensity of both cams:  0.3416603207588196
# Combined mean image intensity variance of both cams:  0.059788450250334114
# Largest delta: (pixel ratio, mean)  [0.881841411337473, 0.3705512583255768]

# %% [markdown]
# ### Machine Hall 03

# %%
dp.create_b_histogram_euroc(euroc_b_metrics,2)

# %%
dp.print_euroc_b_metrics(euroc_b_metrics, 2, False)
# Out:
# Combined pixel ratio of both cams:  0.7047832905433802
# Combined pixel ratio variance on both cams:  0.0664439588484696
# Combined mean image intensity of both cams:  0.344360888004303
# Combined mean image intensity variance of both cams:  0.031072148053317473
# Largest delta: (pixel ratio, mean)  [0.9833021764915706, 0.3705512583255768]

# %% [markdown]
# #### Machine Hall 04

# %%
dp.create_b_histogram_euroc(euroc_b_metrics, 3)

# %%
dp.print_euroc_b_metrics(euroc_b_metrics, 3, False)
# Out:
# Combined pixel ratio of both cams:  0.5876262137959041
# Combined pixel ratio variance on both cams:  0.047738362714971144
# Combined mean image intensity of both cams:  0.29254910349845886
# Combined mean image intensity variance of both cams:  0.025591942423412346
# Largest delta: (pixel ratio, mean)  [0.9833021764915706, 0.3705512583255768]

# %% [markdown]
# #### Machine Hall 05

# %%
dp.create_b_histogram_euroc(euroc_b_metrics, 4)

# %%
dp.print_euroc_b_metrics(euroc_b_metrics, 4, False)
# Out:
# Combined pixel ratio of both cams:  0.582094949215559
# Combined pixel ratio variance on both cams:  0.037007857991388116
# Combined mean image intensity of both cams:  0.2880125045776367
# Combined mean image intensity variance of both cams:  0.024277070576543738
# Largest delta: (pixel ratio, mean)  [0.9833021764915706, 0.3705512583255768]

# %% [markdown]
# ### Vicon Room 1

# %% [markdown]
# #### Vicon Room 1 01

# %%
dp.create_b_histogram_euroc(euroc_b_metrics, 5)

# %%
dp.print_euroc_b_metrics(euroc_b_metrics, 5, False)
# Out:
# Combined pixel ratio of both cams:  0.6387864160002303
# Combined pixel ratio variance on both cams:  0.042100976914603565
# Combined mean image intensity of both cams:  0.5231763124465942
# Combined mean image intensity variance of both cams:  0.023129703938076625
# Largest delta: (pixel ratio, mean)  [1.0198317892896018, 0.3705512583255768]

# %% [markdown]
# #### Vicon Room 1 02

# %%
dp.create_b_histogram_euroc(euroc_b_metrics, 6)

# %%
dp.print_euroc_b_metrics(euroc_b_metrics, 6, False)
# Out:
# Combined pixel ratio of both cams:  0.7892904580195095
# Combined pixel ratio variance on both cams:  0.08981021353203911
# Combined mean image intensity of both cams:  0.5418021082878113
# Combined mean image intensity variance of both cams:  0.049925577227515186
# Largest delta: (pixel ratio, mean)  [1.1680585482050243, 0.3705512583255768]

# %% [markdown]
# #### Vicon Room 1 03

# %%
dp.create_b_histogram_euroc(euroc_b_metrics, 7)

# %%
dp.print_euroc_b_metrics(euroc_b_metrics, 7, False)
# Out:
# Combined pixel ratio of both cams:  0.6000755023487644
# Combined pixel ratio variance on both cams:  0.05604636120729762
# Combined mean image intensity of both cams:  0.44567936658859253
# Combined mean image intensity variance of both cams:  0.032341603482543904
# Largest delta: (pixel ratio, mean)  [1.1680585482050243, 0.3705512583255768]

# %% [markdown]
# ### Vicon Room 2

# %% [markdown]
# #### Vicon Room 2 01

# %%
dp.create_b_histogram_euroc(euroc_b_metrics, 8)

# %%
dp.print_euroc_b_metrics(euroc_b_metrics, 8, False)
# Out:
# Combined pixel ratio of both cams:  0.7312944597746995
# Combined pixel ratio variance on both cams:  0.06918422653927675
# Combined mean image intensity of both cams:  0.45793038606643677
# Combined mean image intensity variance of both cams:  0.039508874833740895
# Largest delta: (pixel ratio, mean)  [1.3278750188757205, 0.3705512583255768]

# %% [markdown]
# #### Vicon Room 2 02

# %%
dp.create_b_histogram_euroc(euroc_b_metrics, 9)

# %%
dp.print_euroc_b_metrics(euroc_b_metrics, 9, False)
# Out:
# Combined pixel ratio of both cams:  0.8065269009826599
# Combined pixel ratio variance on both cams:  0.08745475555791021
# Combined mean image intensity of both cams:  0.4755614399909973
# Combined mean image intensity variance of both cams:  0.04481765427654175
# Largest delta: (pixel ratio, mean)  [1.3379069648305257, 0.3705512583255768]

# %% [markdown]
# #### Vicon Room 2 03

# %%
dp.create_b_histogram_euroc(euroc_b_metrics, 10)

# %%
dp.print_euroc_b_metrics(euroc_b_metrics, 10, False)
# Out:
# Combined pixel ratio of both cams:  0.779687493877856
# Combined pixel ratio variance on both cams:  0.04069807516885855
# Combined mean image intensity of both cams:  0.37012332677841187
# Combined mean image intensity variance of both cams:  0.032885193751077305
# Largest delta: (pixel ratio, mean)  [1.3379069648305257, 0.3705512583255768]

# %% [markdown]
# ## Entropy on brightness metric
# ### Pixel ratio

# %%
dp.print_euroc_entropy(euroc_data_br)
# Out:
# Machine Hall: 1
# Entropy of sequence:  11.75929274282594
# Entropy of sequence:  11.748019039674295
# Machine Hall: 2
# Entropy of sequence:  11.48095275882195
# Entropy of sequence:  11.481771911781049
# Machine Hall: 3
# Entropy of sequence:  11.346793816935175
# Entropy of sequence:  11.341147478973017
# Machine Hall: 4
# Entropy of sequence:  10.955203759557357
# Entropy of sequence:  10.923463562258245
# Machine Hall: 5
# Entropy of sequence:  11.088888595517357
# Entropy of sequence:  11.095712077701394
# Vicon Room 1:  1
# Entropy of sequence:  11.472767167671481
# Entropy of sequence:  11.47414079404511
# Vicon Room 1:  2
# Entropy of sequence:  10.728084703340578
# Entropy of sequence:  10.731272787914566
# Vicon Room 1:  3
# Entropy of sequence:  11.048044462634595
# Entropy of sequence:  11.05176712433771
# Vicon Room 2:  1
# Entropy of sequence:  11.110627368919888
# Entropy of sequence:  11.105910312997882
# Vicon Room 2:  2
# Entropy of sequence:  11.166552297879711
# ...

# %% [markdown]
# ### Grayscale mean

# %%
dp.print_euroc_entropy(euroc_data_m)
# Out:
# Machine Hall: 1
# Entropy of sequence:  11.844644362192215
# Entropy of sequence:  11.845187545244903
# Machine Hall: 2
# Entropy of sequence:  11.569855608330593
# Entropy of sequence:  11.56919771359375
# Machine Hall: 3
# Entropy of sequence:  11.397262210456084
# Entropy of sequence:  11.398743691937565
# Machine Hall: 4
# Entropy of sequence:  10.989394499844774
# Entropy of sequence:  10.988684686772519
# Machine Hall: 5
# Entropy of sequence:  11.148622179991964
# Entropy of sequence:  11.150381968817305
# Vicon Room 1:  1
# Entropy of sequence:  11.506421013825332
# Entropy of sequence:  11.504360574264892
# Vicon Room 1:  2
# Entropy of sequence:  10.738611019130051
# Entropy of sequence:  10.74062404448967
# Vicon Room 1:  3
# Entropy of sequence:  11.069449767427518
# Entropy of sequence:  11.069449767427518
# Vicon Room 2:  1
# Entropy of sequence:  11.153063723087515
# Entropy of sequence:  11.154818109052428
# Vicon Room 2:  2
# Entropy of sequence:  11.195513115596905
# ...

# %% [markdown]
# ## Motion blur metric

# %% [markdown]
# ### Machine Hall
#
# First load data:

# %%
euroc_mb_data = mb.load_euroc_dataset(False)
# Out:
# Scanning next folder current total of images processed:  3682
# Scanning next folder current total of images processed:  7364
# Scanning next folder current total of images processed:  10404
# Scanning next folder current total of images processed:  13444
# Scanning next folder current total of images processed:  16144
# Scanning next folder current total of images processed:  18844
# Scanning next folder current total of images processed:  20877
# Scanning next folder current total of images processed:  22909
# Scanning next folder current total of images processed:  25182
# Scanning next folder current total of images processed:  27455
# Scanning next folder current total of images processed:  30367
# Scanning next folder current total of images processed:  33279
# Scanning next folder current total of images processed:  34989
# Scanning next folder current total of images processed:  36700
# Scanning next folder current total of images processed:  38849
# ...

# %%
dp.create_mb_boxplot(euroc_mb_data[0:5], "EuRoC motion blur data on Machine hall: ")

# %% [markdown]
# ### Vicon Room 1

# %%
dp.create_mb_boxplot(euroc_mb_data[5:8], "EuRoC motion blur data on Vicon Room 1: ")

# %% [markdown]
# ### Vicon Room 2

# %%
print(len(euroc_mb_data))
dp.create_mb_boxplot(euroc_mb_data[8:11], "EuRoC motion blur data on Vicon Room 2: ")
# Out:
# 11

# %% [markdown]
# ## Entropy on motion blur metric

# %%
dp.print_euroc_entropy(euroc_mb_data)
# Out:
# Machine Hall: 1
# Entropy of sequence:  11.84627391135028
# Entropy of sequence:  11.84627391135028
# Machine Hall: 2
# Entropy of sequence:  11.569855608330593
# Entropy of sequence:  11.569855608330593
# Machine Hall: 3
# Entropy of sequence:  11.398743691937565
# Entropy of sequence:  11.398743691937565
# Machine Hall: 4
# Entropy of sequence:  10.989394499844774
# Entropy of sequence:  10.988684686772519
# Machine Hall: 5
# Entropy of sequence:  11.150381968817305
# Entropy of sequence:  11.150381968817305
# Vicon Room 1:  1
# Entropy of sequence:  11.507794640198957
# Entropy of sequence:  11.507794640198957
# Vicon Room 1:  2
# Entropy of sequence:  10.739780609773325
# Entropy of sequence:  10.74062404448967
# Vicon Room 1:  3
# Entropy of sequence:  11.069449767427518
# Entropy of sequence:  11.069449767427518
# Vicon Room 2:  1
# Entropy of sequence:  11.154818109052428
# Entropy of sequence:  11.154818109052428
# Vicon Room 2:  2
# Entropy of sequence:  11.19721669310968
# ...
