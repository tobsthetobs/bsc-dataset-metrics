# %% [markdown]
# # Brightness metric
# #### This note book is intended for loading different datasets and processing them using the python file for calculating the metrics related to brightness

# %%
# Routinely have to update this import so it is seperated from the other imports
import BP_ratio as bp
import dataset_plotting as dp

# %% [markdown]
# # EuRoC

# %% [markdown]
# The EuRoC dataset is accessed at their own website: [EuRoC](https://www.lirmm.fr/aqualoc/)
#
#
# The camera data is shot with a monocular monochromatic camera so no transformations from original colorspace has been performed.

# %%
EuRoC_metrics = bp.load_euroc_dataset(True)
# Out:
# Scanning next folder current total of images processed:  2033
# Scanning next folder current total of images processed:  4065

# %%
dp.create_b_histogram_euroc(EuRoC_metrics)

# %%
dp.print_euroc_b_metrics(EuRoC_metrics, False)
# Out:
# Combined pixel ratio of both cams:  0.5876262137959041
# Combined pixel ratio variance on both cams:  0.047738362714971144
# Combined mean image intensity of both cams:  0.29254910349845886
# Combined mean image intensity variance of both cams:  0.025591942423412346
# Largest delta: (pixel ratio, mean)  (1.019853838147572, 0.4628295600414276)

# %% [markdown]
# # AQUALOC
# Dataset is found at: [AQUALOC](https://seafile.lirmm.fr/d/79b03788f29148ca84e5/?p=%2F)

# %%
aqualoc_metrics = bp.load_aqualoc_dataset(True, "GRAY")
# Out:
# Scanning next folder current total of images processed:  4586
# Scanning next folder current total of images processed:  12728
# Scanning next folder current total of images processed:  17879
# Scanning next folder current total of images processed:  22004
# Scanning next folder current total of images processed:  25462
# Scanning next folder current total of images processed:  27999
# Scanning next folder current total of images processed:  30260

# %%
aq_br, aq_m, delta = aqualoc_metrics

# %%
dp.create_b_histogram_aqualoc(aq_br, "AQUALOC pixel ratio on harbor sequence: ")

# %%
dp.create_b_histogram_aqualoc(aq_m, "AQUALOC mean image intensity on harbor sequence: ")

# %%
dp.aqualoc_b_metrics(aqualoc_metrics, " aqualoc ", True)
# Out:
# Mean of pixel ratio on:   aqualoc  0.7564047801323099
# Mean of image intensity on:   aqualoc  0.31619343
# Variance of pixel ratio on:   aqualoc  0.019578814752746147
# Variance of image intensity on:   aqualoc  0.0004943097
# Largest delta of all sequences: (pixel ratio, mean) (0.7952412519791593, 0.3289475)
# (0.7564047801323099, 0.019578814752746147, 0.31619343, 0.0004943097)

# %% [markdown]
# # AURORA
#
# Dataset can be found at: [AURORA](https://ieee-dataport.org/open-access/aurora-multi-sensor-dataset-robotic-ocean-exploration)
#
# This datasets images are of approx 2000x2000 in resolution, please specify *stop* in parameters.

# %%
aurora_metrics = bp.load_aurora_dataset(False, "GRAY", stop=5000)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000

# %%
aurora_br, aurora_m, aurora_delta = aurora_metrics

# %%
dp.create_b_histogram_aurora(aurora_br)

# %%
dp.create_b_histogram_aurora(aurora_m)
